# %%
import pandas as pd
import json
import numpy as np
from glob import glob

# %%
files = glob('../*.json')
df = pd.read_json(files[2])
df
# Out:
#            mavpackettype  time_boot_ms      roll     pitch       yaw  \
# 0               ATTITUDE       1248630 -0.023365  0.123523 -0.122601
# 1               ATTITUDE       1248730 -0.023374  0.123501 -0.122614
# 2               ATTITUDE       1248830 -0.023289  0.123506 -0.122639
# 3    GLOBAL_POSITION_INT       1248901       NaN       NaN       NaN
# 4               ATTITUDE       1248930 -0.023221  0.123453 -0.122618
# ..                   ...           ...       ...       ...       ...
# 995  GLOBAL_POSITION_INT       1325158       NaN       NaN       NaN
# 996             ATTITUDE       1325230 -0.134453 -0.085341 -1.134202
# 997             ATTITUDE       1325330 -0.124266 -0.072007 -1.054624
# 998             ATTITUDE       1325430 -0.121024 -0.063388 -0.967107
# 999  GLOBAL_POSITION_INT       1325491       NaN       NaN       NaN
#
#      rollspeed  pitchspeed  yawspeed          lat          lon       alt  \
# ...

# %%
df
# Out:
#            mavpackettype  time_boot_ms      roll     pitch       yaw  \
# 0               ATTITUDE       1248630 -0.023365  0.123523 -0.122601
# 1               ATTITUDE       1248730 -0.023374  0.123501 -0.122614
# 2               ATTITUDE       1248830 -0.023289  0.123506 -0.122639
# 3    GLOBAL_POSITION_INT       1248901       NaN       NaN       NaN
# 4               ATTITUDE       1248930 -0.023221  0.123453 -0.122618
# ..                   ...           ...       ...       ...       ...
# 995  GLOBAL_POSITION_INT       1325158       NaN       NaN       NaN
# 996             ATTITUDE       1325230 -0.134453 -0.085341 -1.134202
# 997             ATTITUDE       1325330 -0.124266 -0.072007 -1.054624
# 998             ATTITUDE       1325430 -0.121024 -0.063388 -0.967107
# 999  GLOBAL_POSITION_INT       1325491       NaN       NaN       NaN
#
#      rollspeed  pitchspeed  yawspeed          lat          lon       alt  \
# ...

# %%
time_between_global_pos = df[df['mavpackettype']=='GLOBAL_POSITION_INT']['time_boot_ms'].diff().mean()
print(f'There is an average of {time_between_global_pos} ms between GLOBAL_POSITION_INT messages')
# Out:
# There is an average of 333.0 ms between GLOBAL_POSITION_INT messages

# %%
time_between_att = df[df['mavpackettype']=='ATTITUDE']['time_boot_ms'].diff().mean()
print(f'There is an average of {time_between_att} ms between ATTITUDE messages')
# Out:
# There is an average of 100.0 ms between ATTITUDE messages
